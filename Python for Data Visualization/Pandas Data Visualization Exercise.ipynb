# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
#df3 = pd.DataFrame(np.random.randn(100,2), columns = ['a','b'])
df3 = pd.read_csv('losslessRT.csv')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6100 entries, 0 to 6099
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Permittivity   6100 non-null   int64
#  1   Lambda         6100 non-null   float64
#  2   Theta          6100 non-null   int64
#  3   R              6100 non-null   float64
#  4   T              6100 non-null   float64
#  5   Rs             6100 non-null   float64
#  6   Ts             6100 non-null   float64
#  7   Unnamed: 7     0 non-null      float64
#  8   Unnamed: 8     0 non-null      float64
# dtypes: float64(7), int64(2)
# memory usage: 429.0 KB

# %%
df3.head()
# Out:
#    Permittivity         Lambda  Theta         R         T        Rs        Ts  \
# 0              1  4.500000e-07      0  0.077268  0.922732  0.077268  0.922732
# 1              1  4.600000e-07      0  0.024456  0.975544  0.024456  0.975544
# 2              1  4.600000e-07      0  0.000353  0.999647  0.000353  0.999647
# 3              1  4.700000e-07      0  0.030495  0.969505  0.030495  0.969505
# 4              1  4.700000e-07      0  0.084365  0.915635  0.084365  0.915635
#
#    Unnamed: 7  Unnamed: 8
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df3.plot.scatter(x = 'R', y = 'Rs',s = 25, c = 'green', figsize = (12,3))
# Out:
# <AxesSubplot:xlabel='R', ylabel='Rs'>

# %%
df3['R'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.style.use('ggplot')

# %%
df3['R'].plot.hist(bins = 10, alpha = 0.25)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3[['R','Rs']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df3['R'].plot.density(linewidth = 2.5, ls = '--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3[['R','T']].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
